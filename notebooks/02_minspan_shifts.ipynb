# %% [markdown]
# # How do Minspan FPKM averages shift under different conditions?
#
# If minspans describe sets of coordinated reactions, do these reactions have coregulation which can be captured in the average transcript levels for a minspan?
#
# This script compares average minspan FPKM values between two different transcript readings. It compares which minspans rank higher under different conditions, and sees if the shift is consistent between two data sets of bop27 under aerobic conditions and two datasets under anaerobic conditions.
#
# The model used here iJO1366.
#
# The MinSpans used can either be the set calculated for iJO1366, or the Minspans calculated for the core mobel.

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
from pickle import load
from IPython.display import HTML
import pandas as pd
import json
import visbio

# Have to direct to folder to find module
# %cd /Users/jt/Desktop/palsson_rotation/transAnalysis/
import transAnalysis as ta

filenameroot = \
    '/Users/jt/Desktop/palsson_rotation/transAnalysis/data/'

# This makes it so changed modules are reloaded before lines run.     
# %load_ext autoreload
# %autoreload 2
# Out:
# /Users/jt/Desktop/palsson_rotation/transAnalysis

# %%
# Get model and minspans
model_filename = filenameroot + 'iJO1366.pickle'
f = open(model_filename, "rb")
model = load(f)
f.close()

#minspan_filename = filenameroot + 'MinSpanPathways.xlsx'
#minspan_list = ta.make_minspan_list(minspan_filename)
minspan_filename = filenameroot + 'minspan_EcoliCore.xlsx'
minspan_list = ta.make_minspan_list(minspan_filename,
                                    '2013-11-18_adjust')

# %%
# Quality control, which reactions from minspan can't be found in model
reaction_not_found = []
for minspan in minspan_list:
    for reaction in minspan:
        try:
            model.reactions.get_by_id(reaction)
        except:
            if reaction not in reaction_not_found:
                reaction_not_found.append(reaction)
            else:
                pass
            
# Should report none
print reaction_not_found
# Out:
# []

# %%
# Dict 1, minspan id as key, list of reactons as values
minspan_k_dict = ta.make_minspan_k_dict(minspan_list)

# Dict 2, reaction name as k, with minspans involved as values.
reaction_k_dict, rxn_no_minspan = ta.make_reaction_k_dict(model, minspan_k_dict, report_wo=True)

# %%
# Because we are using iJO as a model, and core for the minspans, this should be a lot
print(len(rxn_no_minspan))
# Out:
# 2499

# %% [markdown]
# ## Comparisons of FPKM minspans averages
#
# 1. bop27_1 vs bop27_2
# 2. anaerob_1 vs anaerob_2
# 3. bop27_1 vs anaerob_1
# 4. bop27_1 vs anaerob_2
# 5. bop27_2 vs anaerob_1
# 6. bop27_2 vs anaerob_2

# %%
# Comparing bop1 vs bop2
fpkm_filename1 = filenameroot + 'bop27_1_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'bop27_2_isoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                   minspan_list, model, 0)
# Out:
# ('R^2 for fpkm values is: ', 0.99625333154656004)
# ('R^2 for rank order is: ', 0.62845849802371534)

# %%
# Comparing bop1 vs an
fpkm_filename1 = filenameroot + 'bop27_1_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'ar_isoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                   minspan_list, model, 0)
# Out:
# ('R^2 for fpkm values is: ', 0.92072612592360803)
# ('R^2 for rank order is: ', 0.11660079051383399)

# %%
# Comparing bop1 vs bop384
fpkm_filename1 = filenameroot + 'bop27_1_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'bop384_isoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                   minspan_list, model, 0)
# Out:
# ('R^2 for fpkm values is: ', 0.76881627191404922)
# ('R^2 for rank order is: ', 0.41007905138339923)

# %%
# Comparing anaerobe1 and bop384
fpkm_filename1 = filenameroot + 'anaerobe1_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'bop384_isoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                   minspan_list, model, 0)
# Out:
# ('R^2 for fpkm values is: ', 0.98446097302347868)
# ('R^2 for rank order is: ', 0.29446640316205536)

# %%
# Comparing anaerob1 vs anaerob2
fpkm_filename1 = filenameroot + 'anaerobe1_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'anaerobe2_isoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                              minspan_list, model)
# Out:
# ('R^2 for fpkm values is: ', 0.99953323104548053)
# ('R^2 for rank order is: ', 0.62747035573122534)

# %%
# Comparing anaerob1 vs anaerob2
fpkm_filename1 = filenameroot + 'anaerobe1_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'an_isoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                              minspan_list, model)
# Out:
# ('R^2 for fpkm values is: ', 0.99352864587626177)
# ('R^2 for rank order is: ', 0.79051383399209485)

# %%
# Comparing bop1 vs anaerob1
fpkm_filename1 = filenameroot + 'bop27_1_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'anaerobe1_isoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                              minspan_list, model)
# Out:
# ('R^2 for fpkm values is: ', 0.77738660367626111)
# ('R^2 for rank order is: ', 0.30434782608695654)

# %%
#Comparing bop1 vs anaerob2
fpkm_filename1 = filenameroot + 'bop27_1_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'anaerobe2_isoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                              minspan_list, model)
# Out:
# ('R^2 for fpkm values is: ', 0.77832151636486802)
# ('R^2 for rank order is: ', 0.036561264822134391)

# %%
#Comparing bop2 vs anaerob1
fpkm_filename2 = filenameroot + 'bop27_2_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'anaerobe1_isoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                              minspan_list, model)
# Out:
# ('R^2 for fpkm values is: ', 0.77738660367626111)
# ('R^2 for rank order is: ', 0.30434782608695654)

# %%
#Comparing bop2 vs anaerob2
fpkm_filename2 = filenameroot + 'bop27_2_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'anaerobe2_isoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                              minspan_list, model)
# Out:
# ('R^2 for fpkm values is: ', 0.77832151636486802)
# ('R^2 for rank order is: ', 0.036561264822134391)

# %%
#Comparing ar vs anaerob1
fpkm_filename2 = filenameroot + 'ar_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'anaerobe1_isoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                   minspan_list, model)
# Out:
# ('R^2 for fpkm values is: ', 0.77738660367626111)
# ('R^2 for rank order is: ', 0.30434782608695654)

# %%
# Comparing bop1 vs rboB
fpkm_filename1 = filenameroot + 'bop27_1_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'rpoBisoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                   minspan_list, model, 0)
# Out:
# ('R^2 for fpkm values is: ', 0.94878519776983783)
# ('R^2 for rank order is: ', 0.4822134387351778)

# %%
# Comparing anaerob1 vs rpob
fpkm_filename1 = filenameroot + 'anaerobe1_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'rpoBisoforms.fpkm_tracking'

ta.fpkm_comparison(fpkm_filename1, fpkm_filename2, 
                              minspan_list, model)
# Out:
# ('R^2 for fpkm values is: ', 0.85547291350668309)
# ('R^2 for rank order is: ', 0.47035573122529645)

# %% [markdown]
# Above, the biological duplicates are very similar, and the comparisons between the conditions produce a scatter that are not aligned and the resulting shifts are reproduced between all combinations.
#
# ## What are the up shifted and downshifted minspans and do they have biological significance?
#
# Starting with WT and anaerobic fpkm data, find the minspans that have the biggest differential expression data.

# %%
# Use bop1 and anerob1 as comparison set
fpkm_filename1 = filenameroot + 'bop27_1_isoforms.fpkm_tracking'
fpkm_filename2 = filenameroot + 'anaerobe1_isoforms.fpkm_tracking'

bop_gene_fpkm_dict = ta.make_gene_fpkm_dict(fpkm_filename1)
bop_reaction_fpkm_dict = ta.make_reaction_fpkm_dict(model,
                                            bop_gene_fpkm_dict)
bop_minspan_rank = ta.make_minspan_fpkm_list(minspan_list,
                                             bop_reaction_fpkm_dict)

ana_gene_fpkm_dict = ta.make_gene_fpkm_dict(fpkm_filename2)
ana_reaction_fpkm_dict = ta.make_reaction_fpkm_dict(model,
                                            ana_gene_fpkm_dict)
ana_minspan_rank = ta.make_minspan_fpkm_list(minspan_list,
                                             ana_reaction_fpkm_dict)

# %%
minspan_ids = range(1, len(minspan_list) + 1)

# bop df
avgs = np.array(zip(*bop_minspan_rank)[0])
bop_minspan_avgs = pd.Series(avgs, index=minspan_ids)
bop_minspan_reactions = pd.Series(zip(*bop_minspan_rank)[1],
                                  index=minspan_ids)
bop_minspan_norm = pd.Series(avgs / max(avgs), index=minspan_ids)
avg_lognorm = np.log2(1 + ((avgs - min(avgs)) / (max(avgs) - min(avgs))))
bop_minspan_lognorm = pd.Series(avg_lognorm, index=minspan_ids)
bop_df = {'Reactions' : bop_minspan_reactions,
          'FPKM avg' : bop_minspan_avgs,
          'FPKM norm' : bop_minspan_norm,
          'FPKM lognorm' : bop_minspan_lognorm}
columns = ['Reactions', 'FPKM avg', 'FPKM norm', 'FPKM lognorm']
bop_df = pd.DataFrame(bop_df, columns=columns, index=minspan_ids)

# anaerobic df
avgs = np.array(zip(*ana_minspan_rank)[0])
ana_minspan_avgs = pd.Series(avgs, index=minspan_ids)
ana_minspan_reactions = pd.Series(zip(*ana_minspan_rank)[1],
                                  index=minspan_ids)
ana_minspan_norm = pd.Series(avgs / max(avgs), index=minspan_ids)
avg_lognorm = np.log2(1 + ((avgs - min(avgs)) / (max(avgs) - min(avgs))))
ana_minspan_lognorm = pd.Series(avg_lognorm, index=minspan_ids)
ana_df = {'Reactions' : ana_minspan_reactions,
          'FPKM avg' : ana_minspan_avgs,
          'FPKM norm' : ana_minspan_norm,
          'FPKM lognorm' : ana_minspan_lognorm}
columns = ['Reactions', 'FPKM avg', 'FPKM norm', 'FPKM lognorm']
ana_df = pd.DataFrame(ana_df, columns=columns, index=minspan_ids)

# %%
#bop_df['bop Rank'] = range(1, len(minspan_list)+1)

# %% [markdown]
# ### WT minspan breakdown

# %%
bop_df.sort(columns='FPKM avg', ascending=False, inplace=True)
HTML(bop_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Reactions</th>
#       <th>FPKM avg</th>
#       <th>FPKM norm</th>
#       <th>FPKM lognorm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>8 </th>
#       <td> [ACALD, ALCD2x, ATPM, ATPS4rpp, CO2tpp, ENO, E...</td>
#       <td> 11742601.542659</td>
#       <td> 1.000000</td>
#       <td> 1.000000</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td> [ACALD, ACONTa, ACONTb, ALCD2x, ATPM, ATPS4rpp...</td>
#       <td> 11020193.517850</td>
#       <td> 0.938480</td>
#       <td> 0.933856</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td> [ACALD, ACALDtpp, ATPS4rpp, ENO, EX_acald_e, E...</td>
#       <td> 10795901.447370</td>
#       <td> 0.919379</td>
#       <td> 0.912687</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td> [ATPS4rpp, D__LACt2pp, ENO, EX_glc_e, EX_h_e, ...</td>
#       <td> 10754239.848704</td>
#       <td> 0.915831</td>
#       <td> 0.908720</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td> [ATPM, ATPS4rpp, CYTBDpp, ENO, EX_glc_e, EX_h_...</td>
#       <td> 10741743.963172</td>
#       <td> 0.914767</td>
#       <td> 0.907528</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td> [ACONTa, ACONTb, AKGDH, ATPS4rpp, CO2tpp, CS, ...</td>
#       <td> 10606844.620041</td>
#       <td> 0.903279</td>
#       <td> 0.894599</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td> [ACALD, ACONTa, ACONTb, ALCD2x, ATPM, CS, ENO,...</td>
#       <td> 10592978.828066</td>
#       <td> 0.902098</td>
#       <td> 0.893263</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td> [ATPS4rpp, D__LACt2pp, ENO, EX_glc_e, EX_h_e, ...</td>
#       <td> 10573772.695040</td>
#       <td> 0.900463</td>
#       <td> 0.891411</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td> [ACONTa, ACONTb, AKGt2rpp, ATPM, CS, CYTBDpp, ...</td>
#       <td> 10570231.739038</td>
#       <td> 0.900161</td>
#       <td> 0.891069</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td> [ATPM, D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_l...</td>
#       <td> 10209277.785417</td>
#       <td> 0.869422</td>
#       <td> 0.855805</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td> [ACALD, ALCD2x, ATPM, ENO, ETOHtrpp, EX_etoh_e...</td>
#       <td> 10173970.550357</td>
#       <td> 0.866415</td>
#       <td> 0.852309</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td> 10154324.895000</td>
#       <td> 0.864742</td>
#       <td> 0.850360</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td> [ATPS4rpp, D__LACt2pp, ENO, EX_glc_e, EX_h_e, ...</td>
#       <td>  9944373.808704</td>
#       <td> 0.846863</td>
#       <td> 0.829365</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td> [ATPM, D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_l...</td>
#       <td>  9741272.295000</td>
#       <td> 0.829567</td>
#       <td> 0.808760</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td> [ACKr, ACt2rpp, ATPM, ATPS4rpp, CYTBDpp, ENO, ...</td>
#       <td>  9671412.421435</td>
#       <td> 0.823618</td>
#       <td> 0.801604</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td>  9614726.407308</td>
#       <td> 0.818790</td>
#       <td> 0.795772</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td>  9538203.101786</td>
#       <td> 0.812273</td>
#       <td> 0.787860</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td> [ADK1, D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_l...</td>
#       <td>  9421126.673214</td>
#       <td> 0.802303</td>
#       <td> 0.775672</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td> [ATPM, CO2tpp, ENO, EX_co2_e, EX_glc_e, EX_h_e...</td>
#       <td>  9382659.818590</td>
#       <td> 0.799027</td>
#       <td> 0.771644</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td>  9370786.028333</td>
#       <td> 0.798016</td>
#       <td> 0.770399</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td>  9363715.744643</td>
#       <td> 0.797414</td>
#       <td> 0.769657</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td> [ADK1, ATPM, ATPS4rpp, CO2tpp, CYTBDpp, EX_co2...</td>
#       <td>  6508760.972720</td>
#       <td> 0.554286</td>
#       <td> 0.433670</td>
#     </tr>
#     <tr>
#       <th>3 </th>
#       <td>                                     [FRD2, SUCDi]</td>
#       <td>  3682291.750000</td>
#       <td> 0.313584</td>
#       <td> 0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Anaerobic minspan breakdown

# %%
ana_df.sort(columns='FPKM avg', ascending=False, inplace=True)
#ana_df.sort_index(inplace=True)
HTML(ana_df.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Reactions</th>
#       <th>FPKM avg</th>
#       <th>FPKM norm</th>
#       <th>FPKM lognorm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5 </th>
#       <td> [ACALD, ALCD2x, ATPM, ENO, ETOHtrpp, EX_etoh_e...</td>
#       <td> 21588603.485179</td>
#       <td> 1.000000</td>
#       <td> 1.000000</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td> [ACALD, ACALDtpp, ATPS4rpp, ENO, EX_acald_e, E...</td>
#       <td> 21039153.440981</td>
#       <td> 0.974549</td>
#       <td> 0.980055</td>
#     </tr>
#     <tr>
#       <th>8 </th>
#       <td> [ACALD, ALCD2x, ATPM, ATPS4rpp, CO2tpp, ENO, E...</td>
#       <td> 20255172.274861</td>
#       <td> 0.938234</td>
#       <td> 0.951110</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td> [ACKr, ACt2rpp, ATPM, ATPS4rpp, CYTBDpp, ENO, ...</td>
#       <td> 18870204.435255</td>
#       <td> 0.874082</td>
#       <td> 0.898512</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td> [ATPM, D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_l...</td>
#       <td> 18540856.491042</td>
#       <td> 0.858826</td>
#       <td> 0.885717</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td> [ATPM, ATPS4rpp, CYTBDpp, ENO, EX_glc_e, EX_h_...</td>
#       <td> 18218489.857096</td>
#       <td> 0.843894</td>
#       <td> 0.873082</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td> [ATPS4rpp, D__LACt2pp, ENO, EX_glc_e, EX_h_e, ...</td>
#       <td> 17662958.043909</td>
#       <td> 0.818161</td>
#       <td> 0.851045</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td> 17279874.614808</td>
#       <td> 0.800417</td>
#       <td> 0.835651</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td> [ATPS4rpp, D__LACt2pp, ENO, EX_glc_e, EX_h_e, ...</td>
#       <td> 17071085.520981</td>
#       <td> 0.790745</td>
#       <td> 0.827191</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td> [ATPS4rpp, D__LACt2pp, ENO, EX_glc_e, EX_h_e, ...</td>
#       <td> 16905238.307648</td>
#       <td> 0.783063</td>
#       <td> 0.820435</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td> [ADK1, D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_l...</td>
#       <td> 16410585.920893</td>
#       <td> 0.760150</td>
#       <td> 0.800097</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td> 16344914.635179</td>
#       <td> 0.757108</td>
#       <td> 0.797375</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td> 16176663.270893</td>
#       <td> 0.749315</td>
#       <td> 0.790377</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td> 15577518.386167</td>
#       <td> 0.721562</td>
#       <td> 0.765181</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td> [ACALD, ACONTa, ACONTb, ALCD2x, ATPM, ATPS4rpp...</td>
#       <td> 14998899.218031</td>
#       <td> 0.694760</td>
#       <td> 0.740423</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td> [ATPM, D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_l...</td>
#       <td> 14791205.459500</td>
#       <td> 0.685140</td>
#       <td> 0.731432</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td> [ATPM, CO2tpp, ENO, EX_co2_e, EX_glc_e, EX_h_e...</td>
#       <td> 14772548.145141</td>
#       <td> 0.684275</td>
#       <td> 0.730621</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td> 14646682.326167</td>
#       <td> 0.678445</td>
#       <td> 0.725142</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td> [ACONTa, ACONTb, AKGt2rpp, ATPM, CS, CYTBDpp, ...</td>
#       <td> 13222629.467142</td>
#       <td> 0.612482</td>
#       <td> 0.661652</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td> [ACALD, ACONTa, ACONTb, ALCD2x, ATPM, CS, ENO,...</td>
#       <td> 11937309.487411</td>
#       <td> 0.552945</td>
#       <td> 0.601845</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td> [ACONTa, ACONTb, AKGDH, ATPS4rpp, CO2tpp, CS, ...</td>
#       <td> 10804791.785231</td>
#       <td> 0.500486</td>
#       <td> 0.547012</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td> [ADK1, ATPM, ATPS4rpp, CO2tpp, CYTBDpp, EX_co2...</td>
#       <td>  7971780.354967</td>
#       <td> 0.369259</td>
#       <td> 0.399959</td>
#     </tr>
#     <tr>
#       <th>3 </th>
#       <td>                                     [FRD2, SUCDi]</td>
#       <td>  1579441.125000</td>
#       <td> 0.073161</td>
#       <td> 0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Minspan difference breakdown

# %%
lognorm_diff_series = bop_minspan_lognorm - ana_minspan_lognorm

diff_df = {'Reactions' : bop_minspan_reactions,
           'bop FPKM' : bop_minspan_avgs,
           'ana FPKM' : ana_minspan_avgs,
           'Lognorm diff' : lognorm_diff_series}

columns = ['Reactions', 'bop FPKM', 'ana FPKM', 'Lognorm diff']

diff_df = pd.DataFrame(diff_df, columns=columns, index = minspan_ids)

diff_df.sort('Lognorm diff', ascending=False, inplace=True)
HTML(diff_df.to_html(float_format=lambda x: '%10.3f' % x))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Reactions</th>
#       <th>bop FPKM</th>
#       <th>ana FPKM</th>
#       <th>Lognorm diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>14</th>
#       <td> [ACONTa, ACONTb, AKGDH, ATPS4rpp, CO2tpp, CS, ...</td>
#       <td>10606844.620</td>
#       <td>10804791.785</td>
#       <td>     0.348</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td> [ACALD, ACONTa, ACONTb, ALCD2x, ATPM, CS, ENO,...</td>
#       <td>10592978.828</td>
#       <td>11937309.487</td>
#       <td>     0.291</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td> [ACONTa, ACONTb, AKGt2rpp, ATPM, CS, CYTBDpp, ...</td>
#       <td>10570231.739</td>
#       <td>13222629.467</td>
#       <td>     0.229</td>
#     </tr>
#     <tr>
#       <th>1 </th>
#       <td> [ACALD, ACONTa, ACONTb, ALCD2x, ATPM, ATPS4rpp...</td>
#       <td>11020193.518</td>
#       <td>14998899.218</td>
#       <td>     0.193</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td> [ATPS4rpp, D__LACt2pp, ENO, EX_glc_e, EX_h_e, ...</td>
#       <td>10754239.849</td>
#       <td>16905238.308</td>
#       <td>     0.088</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td>10154324.895</td>
#       <td>15577518.386</td>
#       <td>     0.085</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td> [ATPM, D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_l...</td>
#       <td> 9741272.295</td>
#       <td>14791205.459</td>
#       <td>     0.077</td>
#     </tr>
#     <tr>
#       <th>8 </th>
#       <td> [ACALD, ALCD2x, ATPM, ATPS4rpp, CO2tpp, ENO, E...</td>
#       <td>11742601.543</td>
#       <td>20255172.275</td>
#       <td>     0.049</td>
#     </tr>
#     <tr>
#       <th>2 </th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td> 9370786.028</td>
#       <td>14646682.326</td>
#       <td>     0.045</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td> [ATPM, CO2tpp, ENO, EX_co2_e, EX_glc_e, EX_h_e...</td>
#       <td> 9382659.819</td>
#       <td>14772548.145</td>
#       <td>     0.041</td>
#     </tr>
#     <tr>
#       <th>9 </th>
#       <td> [ATPS4rpp, D__LACt2pp, ENO, EX_glc_e, EX_h_e, ...</td>
#       <td>10573772.695</td>
#       <td>17662958.044</td>
#       <td>     0.040</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td> [ATPM, ATPS4rpp, CYTBDpp, ENO, EX_glc_e, EX_h_...</td>
#       <td>10741743.963</td>
#       <td>18218489.857</td>
#       <td>     0.034</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td> [ADK1, ATPM, ATPS4rpp, CO2tpp, CYTBDpp, EX_co2...</td>
#       <td> 6508760.973</td>
#       <td> 7971780.355</td>
#       <td>     0.034</td>
#     </tr>
#     <tr>
#       <th>7 </th>
#       <td> [ATPS4rpp, D__LACt2pp, ENO, EX_glc_e, EX_h_e, ...</td>
#       <td> 9944373.809</td>
#       <td>17071085.521</td>
#       <td>     0.002</td>
#     </tr>
#     <tr>
#       <th>3 </th>
#       <td>                                     [FRD2, SUCDi]</td>
#       <td> 3682291.750</td>
#       <td> 1579441.125</td>
#       <td>     0.000</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td> 9538203.102</td>
#       <td>16176663.271</td>
#       <td>    -0.003</td>
#     </tr>
#     <tr>
#       <th>4 </th>
#       <td> [ADK1, D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_l...</td>
#       <td> 9421126.673</td>
#       <td>16410585.921</td>
#       <td>    -0.024</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td> 9363715.745</td>
#       <td>16344914.635</td>
#       <td>    -0.028</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td> [ATPM, D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_l...</td>
#       <td>10209277.785</td>
#       <td>18540856.491</td>
#       <td>    -0.030</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td> [D__LACt2pp, ENO, EX_glc_e, EX_h_e, EX_lac__D_...</td>
#       <td> 9614726.407</td>
#       <td>17279874.615</td>
#       <td>    -0.040</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td> [ACALD, ACALDtpp, ATPS4rpp, ENO, EX_acald_e, E...</td>
#       <td>10795901.447</td>
#       <td>21039153.441</td>
#       <td>    -0.067</td>
#     </tr>
#     <tr>
#       <th>6 </th>
#       <td> [ACKr, ACt2rpp, ATPM, ATPS4rpp, CYTBDpp, ENO, ...</td>
#       <td> 9671412.421</td>
#       <td>18870204.435</td>
#       <td>    -0.097</td>
#     </tr>
#     <tr>
#       <th>5 </th>
#       <td> [ACALD, ALCD2x, ATPM, ENO, ETOHtrpp, EX_etoh_e...</td>
#       <td>10173970.550</td>
#       <td>21588603.485</td>
#       <td>    -0.148</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Map differentially expressed minspans.
#
# Call minspans from their ID (the index in the table).

# %%
upminspan = minspan_k_dict['14']
minspan_for_map = dict()
for rxn in upminspan:
    # Use this just to see the whole minspan
    minspan_for_map[rxn] = 1
    
    # OR, an use the fpkm values for the 'flux' ammount, but make sure you have the right dict.
    # Note that there are Nans, in there, so you wont see the whole minspan.
    #minspan_for_map[rxn] = ana_reaction_fpkm_dict[rxn]
    #minspan_for_map[rxn] = bop_reaction_fpkm_dict[rxn]
    

minspan_map = visbio.Map(flux=minspan_for_map)
minspan_map.view_browser()

# %%
print minspan_for_map
# Out:
# {'EX_for_e': nan, 'EX_etoh_e': nan, 'PYRt2rpp': nan, 'EX_h_e': nan, 'EX_pyr_e': nan, 'EX_glc_e': nan, 'PGM': 8391320.0, 'ACALD': 15244338.699999999, 'PGK': 7615060.0, 'PGI': 5364240.0, 'ALCD2x': 15753202.0, 'ETOHtrpp': nan, 'GAPD': 76171700.0, 'ATPM': nan, 'TPI': 12567900.0, 'ENO': 27977000.0, 'GLCptspp': 47287843.092500001, 'PFK': 8640100.0, 'PFL': 46051924.899999999, 'FBA': 15322870.0, 'PYK': 11377000.0, 'FORtppi': 4475950.0999999996}
